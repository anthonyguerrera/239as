# %% [markdown]
# ## Imports & Setup

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape,AveragePooling2D,Bidirectional,GRU
import keras
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('/frn')
from frn.frn import FRN as FilterResponseNormalization

# %% [markdown]
# ## Data Prep Functions

# %%
def train_data_prep(X,y,sub_sample,average,noise,time_limit):

    total_X = None
    total_y = None

    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:time_limit]
    #print('Shape of X after trimming:',X.shape)

    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)

    total_X = X_max
    total_y = y
    #print('Shape of X after maxpooling:',total_X.shape)

    # Averaging + noise
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.4, X_average.shape)

    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)

    # Subsampling

    for i in range(sub_sample):
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.3, X[:, :,i::sub_sample].shape) if noise else 0.0)

        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))

    #print('Shape of X after subsampling and concatenating:',total_X.shape)
    #print('Shape of Y:',total_y.shape)
    return total_X,total_y


def test_data_prep(X, time_limit):
    total_X = None

    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:time_limit]
    #print('Shape of X after trimming:',X.shape)

    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, 2), axis=3)

    total_X = X_max
    #print('Shape of X after maxpooling:',total_X.shape)

    return total_X

# %% [markdown]
# ## Data Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_test = np.load("/content/drive/MyDrive/c147 final project/X_test.npy")
y_test = np.load("/content/drive/MyDrive/c147 final project/y_test.npy")
person_train_valid = np.load("/content/drive/MyDrive/c147 final project/person_train_valid.npy")
X_train_valid = np.load("/content/drive/MyDrive/c147 final project/X_train_valid.npy")
y_train_valid = np.load("/content/drive/MyDrive/c147 final project/y_train_valid.npy")
person_test = np.load("/content/drive/MyDrive/c147 final project/person_test.npy")

y_train_valid -= 769
y_test -= 769

# %% [markdown]
# ## CNN + LSTM Model
# This model follows this architecture:
# - N * (Conv2D - **Max Pool** - BatchNorm - Dropout)
# - LSTM
# - FC layer
# - Softmax
#
# The model takes parameters to adapt each of the layers.

# %%
def cnn_lstm(num_filters = [32], filter_size = 3, dropout = 0.6, activation_func = 'elu', dense_size = 100, lstm_dropout = 0.4, recurrent_dropout = 0.1, time_limit=800):
  hybrid_cnn_lstm_model = Sequential()

  # Conv layers
  for i in range(len(num_filters)):
    hybrid_cnn_lstm_model.add(Conv2D(filters=num_filters[i], kernel_size=(filter_size,filter_size), padding='same', activation=activation_func, input_shape=(time_limit//2,1,22)))
    hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
    hybrid_cnn_lstm_model.add(BatchNormalization())
    hybrid_cnn_lstm_model.add(Dropout(dropout))

  # LSTM
  hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
  hybrid_cnn_lstm_model.add(Dense((dense_size))) # FC layer with 100 units
  hybrid_cnn_lstm_model.add(Reshape((dense_size,1))) # Reshape my output of FC layer so that it's compatible

  # removing recurrent dropout to speedup GPU
  # hybrid_cnn_lstm_model.add(LSTM(10, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout, input_shape=(dense_size,1), return_sequences=False))
  hybrid_cnn_lstm_model.add(LSTM(10, dropout=lstm_dropout, input_shape=(dense_size,1), return_sequences=False))

  # FC + softmax
  hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  return hybrid_cnn_lstm_model

# %% [markdown]
# ## CNN + GRU Model
# This model follows this architecture:
# - N * (Conv2D - **Avg Pool** - BatchNorm - Dropout)
# - LSTM
# - FC layer
# - Softmax
#
# The model takes parameters to adapt each of the layers.

# %%
def cnn_bi(num_filters = [32], filter_size = 3, dropout = 0.6, activation_func = 'elu', dense_size = 100, lstm_dropout = 0.4, recurrent_dropout = 0.1, time_limit=800):
  hybrid_cnn_lstm_model = Sequential()

  # Conv layers
  for i in range(len(num_filters)):
    hybrid_cnn_lstm_model.add(Conv2D(filters=num_filters[i], kernel_size=(filter_size,filter_size), padding='same', activation=activation_func, input_shape=(time_limit//2,1,22)))
    hybrid_cnn_lstm_model.add(AveragePooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
    hybrid_cnn_lstm_model.add(BatchNormalization())
    hybrid_cnn_lstm_model.add(Dropout(dropout))

  # LSTM
  hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
  hybrid_cnn_lstm_model.add(Dense((dense_size))) # FC layer with 100 units
  hybrid_cnn_lstm_model.add(Reshape((dense_size,1))) # Reshape my output of FC layer so that it's compatible
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(dense_size, return_sequences=True)))
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(90, return_sequences=True)))
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(60, return_sequences=False)))

  # FC + softmax
  hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  return hybrid_cnn_lstm_model

# %% [markdown]
# ## CNN + GRU + LSTM Model (1)
# This model follows this architecture:
# - N * (Conv2D - **AVG** Pool - BatchNorm - Dropout)
# - LSTM
# - GRU
# - FC layer
# - Softmax
#
# The model takes parameters to adapt each of the layers.

# %%
def cnn_lstm_bi(num_filters = [32], filter_size = 3, dropout = 0.6, activation_func = 'elu', dense_size = 100, lstm_dropout = 0.4, recurrent_dropout = 0.1, time_limit=800):
  hybrid_cnn_lstm_model = Sequential()

  # Conv layers
  for i in range(len(num_filters)):
    hybrid_cnn_lstm_model.add(Conv2D(filters=num_filters[i], kernel_size=(filter_size,filter_size), padding='same', activation=activation_func, input_shape=(time_limit//2,1,22)))
    hybrid_cnn_lstm_model.add(AveragePooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
    hybrid_cnn_lstm_model.add(BatchNormalization())
    hybrid_cnn_lstm_model.add(Dropout(dropout))

  # LSTM
  hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
  hybrid_cnn_lstm_model.add(Dense((dense_size))) # FC layer with 100 units
  hybrid_cnn_lstm_model.add(Reshape((dense_size,1))) # Reshape my output of FC layer so that it's compatible
  hybrid_cnn_lstm_model.add(LSTM(10, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout, input_shape=(dense_size,1), return_sequences=True))

  # GRU
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(dense_size, return_sequences=True)))
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(90, return_sequences=True)))
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(60, return_sequences=False)))

  # FC + softmax
  hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  return hybrid_cnn_lstm_model

# %% [markdown]
# ## CNN + GRU + LSTM Model (2)
# This model follows this architecture:
# - N * (Conv2D - **MAX** Pool - BatchNorm - Dropout)
# - LSTM
# - GRU
# - FC layer
# - Softmax
#
# The model takes parameters to adapt each of the layers.

# %%
def cnn_lstm_bi_2(num_filters = [32], filter_size = 3, dropout = 0.6, activation_func = 'elu', dense_size = 100, lstm_dropout = 0.4, recurrent_dropout = 0.1, time_limit=800):
  hybrid_cnn_lstm_model = Sequential()

  # Conv layers
  for i in range(len(num_filters)):
    hybrid_cnn_lstm_model.add(Conv2D(filters=num_filters[i], kernel_size=(filter_size,filter_size), padding='same', activation=activation_func, input_shape=(time_limit//2,1,22)))
    hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
    hybrid_cnn_lstm_model.add(BatchNormalization())
    hybrid_cnn_lstm_model.add(Dropout(dropout))

  # LSTM
  hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
  hybrid_cnn_lstm_model.add(Dense((dense_size))) # FC layer with 100 units
  hybrid_cnn_lstm_model.add(Reshape((dense_size,1))) # Reshape my output of FC layer so that it's compatible
  # getting rid of recurrent dropout
  # hybrid_cnn_lstm_model.add(LSTM(10, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout, input_shape=(dense_size,1), return_sequences=True))
  hybrid_cnn_lstm_model.add(LSTM(10, dropout=lstm_dropout, input_shape=(dense_size,1), return_sequences=True))

  # GRU
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(dense_size, return_sequences=True)))
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(90, return_sequences=True)))
  hybrid_cnn_lstm_model.add(Bidirectional(GRU(60, return_sequences=False)))

  # FC + softmax
  hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  return hybrid_cnn_lstm_model

# %% [markdown]
# ##LSTM

# %%
def lstm(num_filters = [32], filter_size = 3, dropout = 0.6, activation_func = 'elu', dense_size = 100, lstm_dropout = 0.4, recurrent_dropout = 0.1, time_limit=800):
  hybrid_cnn_lstm_model = Sequential()

  # LSTM
  hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
  hybrid_cnn_lstm_model.add(Dense((dense_size))) # FC layer with 100 units
  hybrid_cnn_lstm_model.add(Reshape((dense_size,1))) # Reshape my output of FC layer so that it's compatible
  hybrid_cnn_lstm_model.add(LSTM(10, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout, input_shape=(dense_size,1), return_sequences=False))

  # FC + softmax
  hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  return hybrid_cnn_lstm_model

# %% [markdown]
# ## Data filtering functions
# These functions allow us to create train/valid & test sets with certain parameters. The possible parameters are:
# - `subjects`:
#   - If `None`, include all subjects
#   - If of type `int`, include data from only this subject
#   - If an array of ints, include data from all subjects in array
# - `time_limit`: Specifies the duration of each trial to use. (Max is 1000, defaults to 800)

# %%
def train_val_data(subjects = None, time_limit = 800):
  if subjects is None: filter = lambda x: True
  elif type(subjects) == int: filter = lambda x: person_train_valid[x] == subjects
  else: filter = lambda x: person_train_valid[x] in subjects

  X_train_valid_filtered = np.array([X_train_valid[i] for i in range(len(X_train_valid)) if filter(i)])
  y_train_valid_filtered = np.array([y_train_valid[i] for i in range(len(y_train_valid)) if filter(i)])

  X_train_valid_prep,y_train_valid_prep = train_data_prep(X_train_valid_filtered,y_train_valid_filtered,2,2,True,time_limit)

  num_total = len(X_train_valid_prep)
  num_valid = int(0.10 * num_total)

  ind_valid = np.random.choice(num_total, num_valid, replace=False)
  ind_train = np.array(list(set(range(num_total)).difference(set(ind_valid))))

  (x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
  (y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]

  y_train = to_categorical(y_train, 4)
  y_valid = to_categorical(y_valid, 4)

  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)

  x_train = np.swapaxes(x_train, 1,3)
  x_train = np.swapaxes(x_train, 1,2)
  x_valid = np.swapaxes(x_valid, 1,3)
  x_valid = np.swapaxes(x_valid, 1,2)

  return x_train, y_train, x_valid, y_valid


def test_data(subjects = None, time_limit = 800):
  if subjects is None: filter = lambda x: True
  elif type(subjects) == int: filter = lambda x: person_test[x] == subjects
  else: filter = lambda x: person_test[x] in subjects
  X_test_filtered = np.array([X_test[i] for i in range(len(X_test)) if filter(i)])
  y_test_filtered = np.array([y_test[i] for i in range(len(y_test)) if filter(i)])

  X_test_prep = test_data_prep(X_test_filtered, time_limit)

  y_test_filtered = to_categorical(y_test_filtered, 4)
  x_test_filtered = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)

  x_test_filtered = np.swapaxes(x_test_filtered, 1,3)
  x_test_filtered = np.swapaxes(x_test_filtered, 1,2)

  return x_test_filtered, y_test_filtered

# %%
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
x_te, y_te = test_data(time_limit=time_limit)

print(x_train.shape)
print(x_val.shape)
print(x_te.shape)
# Out:
# Shape of X after averaging+noise and concatenating: (3808, 22, 400)
# I
# (443, 22, 800)
# (443, 22, 800, 1)
# (3808, 400, 1, 22)
# (211, 400, 1, 22)
# (443, 800, 1, 22)

# %% [markdown]
# ## Train & test functions
# These functions allow us to easily train and test a given model. Both of the functions take the model and data as parameters, and for the training we can specify the most important training params:
# - `epochs`
# - `batch_size`
# - `lr`
#
# Both functions return accuracy data.

# %%
def train(model, x_train, y_train, x_val, y_val, epochs = 100, batch_size = 100, lr = 1e-3, verbose = True):
  optimizer = keras.optimizers.Adam(learning_rate=lr)
  model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

  # Train and save train/val accuracies
  train_results = model.fit(x_train,
              y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_val, y_val), verbose=verbose).history

  end_avg_train_acc = sum(train_results['accuracy'][-10:]) / 10
  end_avg_val_acc = sum(train_results['val_accuracy'][-10:]) / 10

  # returning the following for plotting
  trAcc, valAcc, trLoss, valLoss = train_results['accuracy'], train_results['val_accuracy'], train_results['loss'],train_results['val_loss']

  print("Average training accuracy of last 10 epochs: " + str(end_avg_train_acc) + "%")
  print("Average validation accuracy of last 10 epochs: " + str(end_avg_val_acc) + "%")

  return end_avg_train_acc, end_avg_val_acc, trAcc, valAcc, trLoss, valLoss

def test(model, x_test, y_test):
   test_acc = model.evaluate(x_test, y_test, verbose=0)[1]
   return test_acc

# %% [markdown]
# ## Using our models
# Starting here, the rest of the code uses the functions defined earlier to build, train & test models with varying parameters & data.

# %% [markdown]
# ## CNN (All Subjects)

# %%
# hyper params
# Model parameters
num_filters = [25, 50, 100]
filter_size = 5
dropout = 0.55
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.33
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 75
batch_size = 200
lr = 1e-3
verbose = True

# Building the CNN standalone
model = Sequential()

# Conv. block 1
model.add(Conv2D(filters=15, kernel_size=(15,15), padding='same', activation=activation_func, input_shape=(400,1,22)))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.6))

# Conv. block 2
model.add(Conv2D(filters=10, kernel_size=(15,15), padding='same', activation=activation_func))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.6))

# FC+LSTM layers
model.add(Flatten()) # Adding a flattening operation to the output of CNN block
# hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
# hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible

# Output layer with Softmax activation
model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

# Printing the model summary
print("\nBuilding model...")
model.summary()

# run and train instance of simple CNN across all test subjects
print("#### Training model all subjects for CNN")

# model = cnn_lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

# print("\nTesting on data from subject 1.")
# x_te, y_te = test_data(subjects=None, time_limit=time_limit)
# acc = test(model, x_te, y_te)
# print(str(acc) + "% accuracy on data from subject 1.")
print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)

plt.title('Basic CNN model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')

plt.title('Basic CNN model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Building model...
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 400, 1, 15)        74265
#
#  max_pooling2d_2 (MaxPoolin  (None, 134, 1, 15)        0
#  g2D)
#
#  batch_normalization_11 (Ba  (None, 134, 1, 15)        60
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 134, 1, 15)        0
#
#  conv2d_12 (Conv2D)          (None, 134, 1, 10)        33760
#
#  max_pooling2d_3 (MaxPoolin  (None, 45, 1, 10)         0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 45, 1, 10)         40
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 45, 1, 10)         0
#
#  flatten_4 (Flatten)         (None, 450)               0
#
#  dense_7 (Dense)             (None, 4)                 1804
#
# =================================================================
# Total params: 109929 (429.41 KB)
# Trainable params: 109879 (429.21 KB)
# Non-trainable params: 50 (200.00 Byte)
# _________________________________________________________________
# #### Training model all subjects for CNN
#
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/75
# 39/39 [==============================] - 4s 47ms/step - loss: 2.2689 - accuracy: 0.2813 - val_loss: 1.5013 - val_accuracy: 0.3913
# Epoch 2/75
# 39/39 [==============================] - 1s 31ms/step - loss: 1.8425 - accuracy: 0.3239 - val_loss: 1.3518 - val_accuracy: 0.4066
# Epoch 3/75
# 39/39 [==============================] - 1s 29ms/step - loss: 1.6330 - accuracy: 0.3450 - val_loss: 1.2426 - val_accuracy: 0.4634
# 39/39 [==============================] - 1s 33ms/step - loss: 0.7331 - accuracy: 0.7041 - val_loss: 0.5594 - val_accuracy: 0.8014
# Epoch 64/75
# 39/39 [==============================] - 1s 29ms/step - loss: 0.7287 - accuracy: 0.7092 - val_loss: 0.5486 - val_accuracy: 0.7991
# Epoch 65/75
# 39/39 [==============================] - 1s 31ms/step - loss: 0.7311 - accuracy: 0.7141 - val_loss: 0.5464 - val_accuracy: 0.8109
# Epoch 66/75
# 39/39 [==============================] - 1s 33ms/step - loss: 0.7459 - accuracy: 0.6978 - val_loss: 0.5880 - val_accuracy: 0.7837
# Epoch 67/75
# 39/39 [==============================] - 1s 35ms/step - loss: 0.7241 - accuracy: 0.7196 - val_loss: 0.5791 - val_accuracy: 0.7920
# Epoch 68/75
# 39/39 [==============================] - 1s 30ms/step - loss: 0.7121 - accuracy: 0.7178 - val_loss: 0.5554 - val_accuracy: 0.7991
# Epoch 69/75
# 39/39 [==============================] - 1s 32ms/step - loss: 0.7340 - accuracy: 0.7125 - val_loss: 0.5648 - val_accuracy: 0.8026
# Epoch 70/75
# 39/39 [==============================] - 1s 29ms/step - loss: 0.7158 - accuracy: 0.7208 - val_loss: 0.5541 - val_accuracy: 0.8085
# Epoch 71/75
# 39/39 [==============================] - 1s 32ms/step - loss: 0.7058 - accuracy: 0.7178 - val_loss: 0.5681 - val_accuracy: 0.8002
# Epoch 72/75
# 39/39 [==============================] - 1s 29ms/step - loss: 0.7044 - accuracy: 0.7182 - val_loss: 0.5708 - val_accuracy: 0.7825
# Epoch 73/75
# 39/39 [==============================] - 1s 32ms/step - loss: 0.7163 - accuracy: 0.7172 - val_loss: 0.5596 - val_accuracy: 0.7991
# Epoch 74/75
# 39/39 [==============================] - 1s 30ms/step - loss: 0.7000 - accuracy: 0.7263 - val_loss: 0.5513 - val_accuracy: 0.8180
# Epoch 75/75
# 39/39 [==============================] - 1s 29ms/step - loss: 0.7100 - accuracy: 0.7213 - val_loss: 0.5614 - val_accuracy: 0.8097
# Average training accuracy of last 10 epochs: 0.7169162034988403%
# Average validation accuracy of last 10 epochs: 0.7995271861553193%
# Finished training.
#
# Testing on data from all subjects.
# 0.722347617149353% accuracy on data from all subjects.

# %% [markdown]
# ##CNN + GRU

# %%
# hyper params
# Model parameters
num_filters = [25, 50, 100, 200]
filter_size = 5
dropout = 0.6
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.4
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 30
batch_size = 100
lr = 1e-3
verbose = True


# call the cnn+lstm+gru model 2
model = cnn_bi(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('CNN+GRU (Avg Pooling) Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('CNN+GRU (Avg Pooling) Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/30
# 77/77 [==============================] - 19s 77ms/step - loss: 1.2996 - accuracy: 0.3618 - val_loss: 1.2259 - val_accuracy: 0.4563
# Epoch 2/30
# 77/77 [==============================] - 3s 38ms/step - loss: 1.1885 - accuracy: 0.4543 - val_loss: 1.0854 - val_accuracy: 0.5071
# Epoch 3/30
# 77/77 [==============================] - 3s 39ms/step - loss: 1.1546 - accuracy: 0.4775 - val_loss: 1.0474 - val_accuracy: 0.5142
# Epoch 4/30
# 77/77 [==============================] - 3s 39ms/step - loss: 1.1266 - accuracy: 0.4866 - val_loss: 1.0369 - val_accuracy: 0.5378
# Epoch 5/30
# 77/77 [==============================] - 3s 43ms/step - loss: 1.1076 - accuracy: 0.5125 - val_loss: 0.9882 - val_accuracy: 0.5733
# Epoch 6/30
# 77/77 [==============================] - 3s 41ms/step - loss: 1.0782 - accuracy: 0.5338 - val_loss: 0.9630 - val_accuracy: 0.5839
# Epoch 7/30
# 77/77 [==============================] - 3s 39ms/step - loss: 1.0550 - accuracy: 0.5440 - val_loss: 0.9077 - val_accuracy: 0.6265
# Epoch 8/30
# 77/77 [==============================] - 3s 40ms/step - loss: 1.0178 - accuracy: 0.5701 - val_loss: 0.9215 - val_accuracy: 0.6135
# Epoch 9/30
# 77/77 [==============================] - 3s 43ms/step - loss: 1.0132 - accuracy: 0.5760 - val_loss: 0.8328 - val_accuracy: 0.6738
# Epoch 10/30
# 77/77 [==============================] - 3s 43ms/step - loss: 0.9706 - accuracy: 0.6017 - val_loss: 0.8154 - val_accuracy: 0.6702
# Epoch 11/30
# 77/77 [==============================] - 3s 40ms/step - loss: 0.9448 - accuracy: 0.6069 - val_loss: 0.8182 - val_accuracy: 0.6619
# Epoch 12/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.9282 - accuracy: 0.6172 - val_loss: 0.7577 - val_accuracy: 0.6891
# Epoch 13/30
# 77/77 [==============================] - 3s 44ms/step - loss: 0.9084 - accuracy: 0.6303 - val_loss: 0.8169 - val_accuracy: 0.6785
# Epoch 14/30
# 77/77 [==============================] - 3s 42ms/step - loss: 0.8889 - accuracy: 0.6409 - val_loss: 0.7116 - val_accuracy: 0.7305
# Epoch 15/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.8650 - accuracy: 0.6546 - val_loss: 0.6945 - val_accuracy: 0.7305
# Epoch 16/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.8453 - accuracy: 0.6623 - val_loss: 0.6805 - val_accuracy: 0.7423
# Epoch 17/30
# 77/77 [==============================] - 3s 44ms/step - loss: 0.8352 - accuracy: 0.6688 - val_loss: 0.6338 - val_accuracy: 0.7719
# Epoch 18/30
# 77/77 [==============================] - 3s 43ms/step - loss: 0.8273 - accuracy: 0.6664 - val_loss: 0.6803 - val_accuracy: 0.7317
# Epoch 19/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.8025 - accuracy: 0.6770 - val_loss: 0.5806 - val_accuracy: 0.7931
# Epoch 20/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.7789 - accuracy: 0.6874 - val_loss: 0.5958 - val_accuracy: 0.7742
# Epoch 21/30
# 77/77 [==============================] - 3s 43ms/step - loss: 0.7609 - accuracy: 0.6954 - val_loss: 0.5357 - val_accuracy: 0.8121
# Epoch 22/30
# 77/77 [==============================] - 3s 44ms/step - loss: 0.7420 - accuracy: 0.7091 - val_loss: 0.5100 - val_accuracy: 0.8097
# Epoch 23/30
# 77/77 [==============================] - 3s 40ms/step - loss: 0.7449 - accuracy: 0.7061 - val_loss: 0.5163 - val_accuracy: 0.8156
# Epoch 24/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.7138 - accuracy: 0.7113 - val_loss: 0.4965 - val_accuracy: 0.8310
# Epoch 25/30
# 77/77 [==============================] - 3s 42ms/step - loss: 0.7127 - accuracy: 0.7168 - val_loss: 0.5059 - val_accuracy: 0.8132
# Epoch 26/30
# 77/77 [==============================] - 4s 55ms/step - loss: 0.6738 - accuracy: 0.7326 - val_loss: 0.4544 - val_accuracy: 0.8475
# Epoch 27/30
# 77/77 [==============================] - 4s 46ms/step - loss: 0.6895 - accuracy: 0.7335 - val_loss: 0.4674 - val_accuracy: 0.8416
# Epoch 28/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.6629 - accuracy: 0.7411 - val_loss: 0.4102 - val_accuracy: 0.8593
# Epoch 29/30
# 77/77 [==============================] - 3s 39ms/step - loss: 0.6628 - accuracy: 0.7354 - val_loss: 0.4377 - val_accuracy: 0.8487
# Epoch 30/30
# 77/77 [==============================] - 4s 46ms/step - loss: 0.6486 - accuracy: 0.7402 - val_loss: 0.3532 - val_accuracy: 0.8877
# Average training accuracy of last 10 epochs: 0.7221565485000611%
# Average validation accuracy of last 10 epochs: 0.8366430282592774%
# Finished training.
#
# Testing on data from all subjects.
# 0.6568848490715027% accuracy on data from all subjects.

# %% [markdown]
# ##CNN + LSTM (All Subjects)

# %%
# Model parameters
num_filters = [50, 100]
filter_size = 5
dropout = 0.58
activation_func = 'elu'
dense_size = 10
lstm_dropout = 0.33
#recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 50
batch_size = 100
lr = 1e-3
verbose = True

print("#### Training model ON all subjects. ###")
print("\nBuilding model...")
model = cnn_lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

#print("\nTesting on data from subject 1.")
#x_te, y_te = test_data(subjects=1,time_limit=time_limit)
#acc = test(model, x_te, y_te)
#print(str(acc) + "% accuracy on data subject 1.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('CNN + LSTM ALL SUBJECT Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('CNN + LSTM ALL Subject Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# #### Training model ON all subjects. ###
#
# Building model...
#
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/50
# 77/77 [==============================] - 6s 23ms/step - loss: 1.3625 - accuracy: 0.3097 - val_loss: 1.3055 - val_accuracy: 0.3865
# Epoch 2/50
# 77/77 [==============================] - 1s 13ms/step - loss: 1.2818 - accuracy: 0.3920 - val_loss: 1.1969 - val_accuracy: 0.4362
# Epoch 3/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.2142 - accuracy: 0.4232 - val_loss: 1.1651 - val_accuracy: 0.4622
# Epoch 4/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.1712 - accuracy: 0.4611 - val_loss: 1.1180 - val_accuracy: 0.5083
# Epoch 5/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.1350 - accuracy: 0.4926 - val_loss: 1.0575 - val_accuracy: 0.5449
# Epoch 6/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.1126 - accuracy: 0.5074 - val_loss: 1.0035 - val_accuracy: 0.5946
# Epoch 7/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.0632 - accuracy: 0.5398 - val_loss: 0.9463 - val_accuracy: 0.6253
# Epoch 8/50
# 77/77 [==============================] - 1s 12ms/step - loss: 1.0105 - accuracy: 0.5716 - val_loss: 0.8661 - val_accuracy: 0.6572
# Epoch 9/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.9999 - accuracy: 0.5788 - val_loss: 0.8368 - val_accuracy: 0.6856
# Epoch 10/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.9525 - accuracy: 0.6005 - val_loss: 0.8007 - val_accuracy: 0.7080
# Epoch 11/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.9199 - accuracy: 0.6206 - val_loss: 0.7519 - val_accuracy: 0.7352
# Epoch 12/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.8916 - accuracy: 0.6380 - val_loss: 0.7176 - val_accuracy: 0.7541
# Epoch 13/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.8669 - accuracy: 0.6535 - val_loss: 0.6698 - val_accuracy: 0.7861
# Epoch 14/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.8559 - accuracy: 0.6522 - val_loss: 0.6578 - val_accuracy: 0.7872
# Epoch 15/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.8338 - accuracy: 0.6676 - val_loss: 0.6421 - val_accuracy: 0.7908
# Epoch 16/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.8166 - accuracy: 0.6789 - val_loss: 0.6110 - val_accuracy: 0.8014
# Epoch 17/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0.7818 - accuracy: 0.6907 - val_loss: 0.5842 - val_accuracy: 0.8156
# Epoch 18/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.7596 - accuracy: 0.6967 - val_loss: 0.5586 - val_accuracy: 0.8180
# Epoch 19/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.7548 - accuracy: 0.7012 - val_loss: 0.5380 - val_accuracy: 0.8345
# Epoch 20/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.7342 - accuracy: 0.7062 - val_loss: 0.5051 - val_accuracy: 0.8522
# Epoch 21/50
# 77/77 [==============================] - 1s 12ms/step - loss: 0.7273 - accuracy: 0.7138 - val_loss: 0.4790 - val_accuracy: 0.8617
# Epoch 22/50
# 77/77 [==============================] - 1s 13ms/step - loss: 0
50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4693 - accuracy: 0.8269 - val_loss: 0.2689 - val_accuracy: 0.9113
# Epoch 49/50
# 77/77 [==============================] - 1s 14ms/step - loss: 0.4753 - accuracy: 0.8244 - val_loss: 0.2444 - val_accuracy: 0.9421
# Epoch 50/50
# 77/77 [==============================] - 1s 15ms/step - loss: 0.4572 - accuracy: 0.8289 - val_loss: 0.2294 - val_accuracy: 0.9326
# Average training accuracy of last 10 epochs: 0.8172708094120026%
# Average validation accuracy of last 10 epochs: 0.9313238680362701%
# Finished training.
#
# Testing on data from all subjects.
# 0.7020316123962402% accuracy on data from all subjects.

# %% [markdown]
# ## CNN + LSTM (One Subject, Testing on One Subject + All)

# %%
# hyper params
# Model parameters
num_filters = [25, 50, 100]
filter_size = 5
dropout = 0.55
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.33
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 60
batch_size = 200
lr = 1e-3
verbose = True

# Building the CNN standalone
model = Sequential()

# Conv. block 1
model.add(Conv2D(filters=15, kernel_size=(15,15), padding='same', activation=activation_func, input_shape=(400,1,22)))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.6))

# Conv. block 2
model.add(Conv2D(filters=10, kernel_size=(15,15), padding='same', activation=activation_func))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.6))

# FC+LSTM layers
model.add(Flatten()) # Adding a flattening operation to the output of CNN block
# hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
# hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible

# Output layer with Softmax activation
model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

# Printing the model summary
print("\nBuilding model...")
model.summary()

# run and train instance of simple CNN across all test subjects
print("#### Training model all subjects for CNN")

# model = cnn_lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=1, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

print("\nTesting on data from subject 1.")
x_te, y_te = test_data(subjects=1,time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data subject 1.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('CNN + LSTM One Person Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('CNN + LSTM One Person Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Building model...
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 400, 1, 15)        74265
#
#  max_pooling2d_21 (MaxPooli  (None, 134, 1, 15)        0
#  ng2D)
#
#  batch_normalization_15 (Ba  (None, 134, 1, 15)        60
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 134, 1, 15)        0
#
#  conv2d_22 (Conv2D)          (None, 134, 1, 10)        33760
#
#  max_pooling2d_22 (MaxPooli  (None, 45, 1, 10)         0
#  ng2D)
#
#  batch_normalization_16 (Ba  (None, 45, 1, 10)         40
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 45, 1, 10)         0
#
#  flatten_13 (Flatten)        (None, 450)               0
#
#  dense_17 (Dense)            (None, 4)                 1804
#
# =================================================================
# Total params: 109929 (429.41 KB)
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5843 - accuracy: 0.7694 - val_loss: 0.3368 - val_accuracy: 0.9255
# Epoch 58/60
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5184 - accuracy: 0.7941 - val_loss: 0.3335 - val_accuracy: 0.9468
# Epoch 59/60
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5433 - accuracy: 0.7882 - val_loss: 0.3401 - val_accuracy: 0.9362
# Epoch 60/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5214 - accuracy: 0.7988 - val_loss: 0.3158 - val_accuracy: 0.9468
# Average training accuracy of last 10 epochs: 0.7819999933242798%
# Average validation accuracy of last 10 epochs: 0.9234042644500733%
# Finished training.
#
# Testing on data from subject 1.
# 0.41999998688697815% accuracy on data subject 1.
#
# Testing on data from all subjects.
# 0.3724604845046997% accuracy on data from all subjects.

# %% [markdown]
# ## CNN + LSTM (Trained on Subjects 1-6, Testing on Subjects 7-9 + All)
# Please ignore wrong-named graphs!

# %%
# hyper params
# Model parameters
num_filters = [25, 50, 100]
filter_size = 5
dropout = 0.55
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.33
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 60
batch_size = 200
lr = 1e-3
verbose = True

# Building the CNN standalone
model = Sequential()

# Conv. block 1
model.add(Conv2D(filters=15, kernel_size=(15,15), padding='same', activation=activation_func, input_shape=(400,1,22)))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.6))

# Conv. block 2
model.add(Conv2D(filters=10, kernel_size=(15,15), padding='same', activation=activation_func))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.6))

# FC+LSTM layers
model.add(Flatten()) # Adding a flattening operation to the output of CNN block
# hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
# hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible

# Output layer with Softmax activation
model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

# Printing the model summary
print("\nBuilding model...")
model.summary()

# run and train instance of simple CNN across all test subjects
print("#### Training model all subjects for CNN")

# model = cnn_lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=[0, 1, 2, 3, 4, 5], time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

print("\nTesting on data from subject 1.")
x_te, y_te = test_data(subjects=[6, 7, 8],time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data subject 1.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('CNN + LSTM Persons 7-9 Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('CNN + LSTM 7-9 Person Loss (Training on Person 1-5)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Building model...
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 400, 1, 15)        74265
#
#  max_pooling2d_23 (MaxPooli  (None, 134, 1, 15)        0
#  ng2D)
#
#  batch_normalization_17 (Ba  (None, 134, 1, 15)        60
#  tchNormalization)
#
#  dropout_23 (Dropout)        (None, 134, 1, 15)        0
#
#  conv2d_24 (Conv2D)          (None, 134, 1, 10)        33760
#
#  max_pooling2d_24 (MaxPooli  (None, 45, 1, 10)         0
#  ng2D)
#
#  batch_normalization_18 (Ba  (None, 45, 1, 10)         40
#  tchNormalization)
#
#  dropout_24 (Dropout)        (None, 45, 1, 10)         0
#
#  flatten_14 (Flatten)        (None, 450)               0
#
#  dense_18 (Dense)            (None, 4)                 1804
#
# =================================================================
# Total params: 109929 (429.41 KB)
# Trainable params: 109879 (429.21 KB)
# Non-trainable params: 50 (200.00 Byte)
# _________________________________________________________________
# #### Training model all subjects for CNN
#
# Building train/val data
# Shape of X after averaging+noise and concatenating: (2828, 22, 400)
# Using 5091 training examples & 565 validation examples.
#
# Training...
# Epoch 1/60
# 26/26 [==============================] - 4s 86ms/step - loss: 2.2964 - accuracy: 0.2783 - val_loss: 1.9956 - val_accuracy: 0.2991
# Epoch 2/60
# 26/26 [==============================] - 1s 31ms/step - loss: 1.9224 - accuracy: 0.3159 - val_loss: 1.6059 - val_accuracy: 0.3522
# Epoch 3/60
# 26/26 [==============================] - 1s 32ms/step - loss: 1.7237 - accuracy: 0.3324 - val_loss: 1.3644 - val_accuracy: 0.3858
# Epoch 4/60
# 26/26 [==============================] - 1s 31ms/step - loss: 1.6122 - accuracy: 0.3426 - val_loss: 1.3190 - val_accuracy: 0.4000
# Epoch 5/60
# 26/26 [==============================] - 1s 31ms/step - loss: 1.5180 - accuracy: 0.3650 - val_loss: 1.2373 - val_accuracy: 0.4602
# Epoch 6/60
# 26/26 [==============================] - 1s 30ms/step - loss: 1.4124 - accuracy: 0.3834 - val_loss: 1.2051 - val_accuracy: 0.4690
# Epoch 7/60
# 26/26 [==============================] - 1s 31ms/step - loss: 1.3276 - accuracy: 0.4243 - val_loss: 1.1553 - val_accuracy: 0.5097
# Epoch 8/60
# 26/26 [==============================] - 1s 32ms/step - loss: 1.2831 - accuracy: 0.4313 - val_loss: 1.1175 - val_accuracy: 0.5504
# Epoch 9/60
# 26/26 [==============================] - 1s 33ms/step - loss: 1.2367 - accuracy: 0.4557 - val_loss: 1.0910 - val_accuracy: 0.5416
# Epoch 10/60
# 26/26 [==============================] - 1s 33ms/step - loss: 1.1745 - accuracy: 0.4881 - val_loss: 1.0935 - val_accuracy: 0.5398
# Epoch 11/60
# 26/26 [==============================] - 1s 33ms/step - loss: 1.1311 - accuracy: 0.5109 - val_loss: 1.0467 - val_accuracy: 0.5805
# Epoch 12/60
# 26/26 [==============================] - 1s 32ms/step - loss: 1.1030 - accuracy: 0.5327 - val_loss: 1.0432 - val_accuracy: 0.5965
# Epoch 13/60
# 26/26 [==============================] - 1s 32ms/step - loss: 1.0768 - accuracy: 0.5413 - val_loss: 1.0070 - val_accuracy: 0.5947
# 26/26 [==============================] - 1s 32ms/step - loss: 0.7378 - accuracy: 0.7089 - val_loss: 0.5595 - val_accuracy: 0.8195
# Epoch 60/60
# 26/26 [==============================] - 1s 34ms/step - loss: 0.7109 - accuracy: 0.7181 - val_loss: 0.5538 - val_accuracy: 0.8035
# Average training accuracy of last 10 epochs: 0.7051856219768524%
# Average validation accuracy of last 10 epochs: 0.7904424726963043%
# Finished training.
#
# Testing on data from subject 1.
# 0.5646258592605591% accuracy on data subject 1.
#
# Testing on data from all subjects.
# 0.6455981731414795% accuracy on data from all subjects.

# %% [markdown]
# #CNN + LSTM + GRU (Max Pool)

# %%
# hyper params
# Model parameters
num_filters = [25, 50, 100, 200]
filter_size = 5
dropout = 0.6
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.4
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 100
batch_size = 200
lr = 1e-3
verbose = True


# call the cnn+lstm+gru model 2
model = cnn_lstm_bi_2(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('CNN+LSTM+GRU Max Pooling Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('CNN+LSTM+GRU Max Pooling Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/100
# 39/39 [==============================] - 19s 123ms/step - loss: 1.3736 - accuracy: 0.2840 - val_loss: 1.3266 - val_accuracy: 0.3511
# Epoch 2/100
# 39/39 [==============================] - 2s 64ms/step - loss: 1.3303 - accuracy: 0.3492 - val_loss: 1.2681 - val_accuracy: 0.4078
# Epoch 3/100
# 39/39 [==============================] - 3s 64ms/step - loss: 1.2703 - accuracy: 0.4022 - val_loss: 1.2357 - val_accuracy: 0.4208
# Epoch 4/100
# 39/39 [==============================] - 3s 67ms/step - loss: 1.2262 - accuracy: 0.4250 - val_loss: 1.1710 - val_accuracy: 0.4645
# Epoch 5/100
# 39/39 [==============================] - 2s 64ms/step - loss: 1.1983 - accuracy: 0.4483 - val_loss: 1.1514 - val_accuracy: 0.4929
# Epoch 6/100
# 39/39 [==============================] - 2s 63ms/step - loss: 1.1799 - accuracy: 0.4584 - val_loss: 1.1585 - val_accuracy: 0.4929
# Epoch 7/100
# 39/39 [==============================] - 2s 63ms/step - loss: 1.1633 - accuracy: 0.4626 - val_loss: 1.1063 - val_accuracy: 0.4917
# Epoch 8/100
# Average validation accuracy of last 10 epochs: 0.8619385302066803%
# Finished training.
#
# Testing on data from all subjects.
# 0.6794582605361938% accuracy on data from all subjects.

# %% [markdown]
# #CNN + LSTM + GRU (Avg Pooling)

# %%
# hyper params
# Model parameters
num_filters = [50, 100, 200]
filter_size = 5
dropout = 0.5
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.3
recurrent_dropout = 0.2
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 20
batch_size = 100
lr = 1e-3
verbose = True


# call the cnn+lstm+gru model 2
model = cnn_lstm_bi(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('CNN+GRU (Avg Pooling) Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('CNN+GRU (Avg Pooling) Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm_41 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/20
# 77/77 [==============================] - 50s 452ms/step - loss: 1.2561 - accuracy: 0.4144 - val_loss: 1.1667 - val_accuracy: 0.4870
# Epoch 2/20
# 77/77 [==============================] - 29s 371ms/step - loss: 1.0998 - accuracy: 0.5269 - val_loss: 0.9966 - val_accuracy: 0.5721
# Epoch 3/20
# 77/77 [==============================] - 31s 404ms/step - loss: 0.9849 - accuracy: 0.5950 - val_loss: 0.8940 - val_accuracy: 0.6383
# Epoch 4/20
# 77/77 [==============================] - 29s 374ms/step - loss: 0.9042 - accuracy: 0.6363 - val_loss: 0.7908 - val_accuracy: 0.7033
# Epoch 5/20
# 77/77 [==============================] - 29s 374ms/step - loss: 0.8353 - accuracy: 0.6757 - val_loss: 0.9114 - val_accuracy: 0.6560
# Epoch 6/20
# 77/77 [==============================] - 29s 379ms/step - loss: 0.7771 - accuracy: 0.7009 - val_loss: 0.6508 - val_accuracy: 0.7506
# Epoch 7/20
# 77/77 [==============================] - 30s 387ms/step - loss: 0.7211 - accuracy: 0.7212 - val_loss: 0.5988 - val_accuracy: 0.7695
# Epoch 8/20
# 77/77 [==============================] - 29s 373ms/step - loss: 0.7003 - accuracy: 0.7327 - val_loss: 0.5692 - val_accuracy: 0.7825
# Epoch 9/20
# 77/77 [==============================] - 28s 369ms/step - loss: 0.6196 - accuracy: 0.7632 - val_loss: 0.4907 - val_accuracy: 0.8109
# Epoch 10/20
# 77/77 [==============================] - 30s 384ms/step - loss: 0.5558 - accuracy: 0.7876 - val_loss: 0.5616 - val_accuracy: 0.7872
# Epoch 11/20
# 77/77 [==============================] - 30s 392ms/step - loss: 0.5087 - accuracy: 0.8035 - val_loss: 0.4616 - val_accuracy: 0.8203
# Epoch 12/20
# 77/77 [==============================] - 28s 365ms/step - loss: 0.4806 - accuracy: 0.8239 - val_loss: 0.2793 - val_accuracy: 0.8913
# Epoch 13/20
# 77/77 [==============================] - 28s 370ms/step - loss: 0.4253 - accuracy: 0.8416 - val_loss: 0.5265 - val_accuracy: 0.8050
# Epoch 14/20
# 77/77 [==============================] - 28s 366ms/step - loss: 0.4162 - accuracy: 0.8448 - val_loss: 0.2349 - val_accuracy: 0.9031
# Epoch 15/20
# 77/77 [==============================] - 29s 372ms/step - loss: 0.3609 - accuracy: 0.8620 - val_loss: 0.1581 - val_accuracy: 0.9444
# Epoch 16/20
# 77/77 [==============================] - 29s 369ms/step - loss: 0.3295 - accuracy: 0.8800 - val_loss: 0.4286 - val_accuracy: 0.8345
# Epoch 17/20
# 77/77 [==============================] - 30s 390ms/step - loss: 0.3224 - accuracy: 0.8823 - val_loss: 0.1954 - val_accuracy: 0.9208
# Epoch 18/20
# 77/77 [==============================] - 28s 367ms/step - loss: 0.3116 - accuracy: 0.8839 - val_loss: 0.2315 - val_accuracy: 0.9078
# Epoch 19/20
# 77/77 [==============================] - 28s 367ms/step - loss: 0.2895 - accuracy: 0.8935 - val_loss: 0.1852 - val_accuracy: 0.9326
# Epoch 20/20
# 77/77 [==============================] - 30s 393ms/step - loss: 0.2370 - accuracy: 0.9134 - val_loss: 0.1177 - val_accuracy: 0.9586
# Average training accuracy of last 10 epochs: 0.8628841638565063%
# Average validation accuracy of last 10 epochs: 0.8918439686298371%
# Finished training.
#
# Testing on data from all subjects.
# 0.6681715846061707% accuracy on data from all subjects.

# %% [markdown]
# # FRN

# %%
# hyper params
# Model parameters
num_filters = [25, 50, 100]
filter_size = 5
dropout = 0.55
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.33
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 75
batch_size = 200
lr = 1e-3
verbose = True

# Building the CNN standalone
model = Sequential()

# Conv. block 1
model.add(Conv2D(filters=15, kernel_size=(15,15), padding='same', activation=activation_func, input_shape=(400,1,22)))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(FilterResponseNormalization())
model.add(Dropout(0.6))

# Conv. block 2
model.add(Conv2D(filters=10, kernel_size=(15,15), padding='same', activation=activation_func))
model.add(MaxPooling2D(pool_size=(3,3), padding='same'))
model.add(FilterResponseNormalization())
model.add(Dropout(0.6))

# FC+LSTM layers
model.add(Flatten()) # Adding a flattening operation to the output of CNN block
# hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
# hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible

# Output layer with Softmax activation
model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

# Printing the model summary
print("\nBuilding model...")
model.summary()

# run and train instance of simple CNN across all test subjects
print("#### Training model all subjects for CNN")

# model = cnn_lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

# print("\nTesting on data from subject 1.")
# x_te, y_te = test_data(subjects=None, time_limit=time_limit)
# acc = test(model, x_te, y_te)
# print(str(acc) + "% accuracy on data from subject 1.")
print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)

plt.title('FRN Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')

plt.title('FRN Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Building model...
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 400, 1, 15)        74265
#
#  max_pooling2d_4 (MaxPoolin  (None, 134, 1, 15)        0
#  g2D)
#
#  frn_4 (FRN)                 (None, 134, 1, 15)        45
#
#  dropout_4 (Dropout)         (None, 134, 1, 15)        0
#
#  conv2d_5 (Conv2D)           (None, 134, 1, 10)        33760
#
#  max_pooling2d_5 (MaxPoolin  (None, 45, 1, 10)         0
#  g2D)
#
#  frn_5 (FRN)                 (None, 45, 1, 10)         30
#
#  dropout_5 (Dropout)         (None, 45, 1, 10)         0
#
#  flatten_5 (Flatten)         (None, 450)               0
#
#  dense_8 (Dense)             (None, 4)                 1804
#
# =================================================================
# Total params: 109904 (429.31 KB)
# Trainable params: 109904 (429.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# #### Training model all subjects for CNN
#
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/75
# 39/39 [==============================] - 4s 48ms/step - loss: 1.9499 - accuracy: 0.2606 - val_loss: 1.3655 - val_accuracy: 0.3109
# Epoch 2/75
# 39/39 [==============================] - 1s 33ms/step - loss: 1.5274 - accuracy: 0.2837 - val_loss: 1.3320 - val_accuracy: 0.3806
# Epoch 3/75
# 39/39 [==============================] - 1s 31ms/step - loss: 1.4367 - accuracy: 0.3114 - val_loss: 1.3123 - val_accuracy: 0.3771
# Epoch 4/75
# 39/39 [==============================] - 1s 32ms/step - loss: 1.3733 - accuracy: 0.3243 - val_loss: 1.2994 - val_accuracy: 0.4066
# Epoch 5/75
# 39/39 [==============================] - 1s 33ms/step - loss: 1.3393 - accuracy: 0.3517 - val_loss: 1.2576 - val_accuracy: 0.4173
# Epoch 6/75
# 39/39 [==============================] - 1s 32ms/step - loss: 1.2957 - accuracy: 0.3930 - val_loss: 1.2220 - val_accuracy: 0.4669
# Epoch 7/75
# 39/39 [==============================] - 1s 36ms/step - loss: 1.2673 - accuracy: 0.4066 - val_loss: 1.1971 - val_accuracy: 0.4480
# Epoch 8/75
# 39/39 [==============================] - 1s 33ms/step - loss: 1.2425 - accuracy: 0.4237 - val_loss: 1.1973 - val_accuracy: 0.4468
75
# 39/39 [==============================] - 1s 32ms/step - loss: 0.8813 - accuracy: 0.6396 - val_loss: 0.7436 - val_accuracy: 0.7104
# Epoch 70/75
# 39/39 [==============================] - 1s 35ms/step - loss: 0.8772 - accuracy: 0.6460 - val_loss: 0.7748 - val_accuracy: 0.7092
# Epoch 71/75
# 39/39 [==============================] - 1s 38ms/step - loss: 0.8760 - accuracy: 0.6504 - val_loss: 0.7355 - val_accuracy: 0.7340
# Epoch 72/75
# 39/39 [==============================] - 1s 38ms/step - loss: 0.8798 - accuracy: 0.6466 - val_loss: 0.7274 - val_accuracy: 0.7222
# Epoch 73/75
# 39/39 [==============================] - 1s 37ms/step - loss: 0.8567 - accuracy: 0.6418 - val_loss: 0.7423 - val_accuracy: 0.7057
# Epoch 74/75
# 39/39 [==============================] - 1s 32ms/step - loss: 0.8591 - accuracy: 0.6496 - val_loss: 0.7285 - val_accuracy: 0.7376
# Epoch 75/75
# 39/39 [==============================] - 1s 32ms/step - loss: 0.8511 - accuracy: 0.6514 - val_loss: 0.7489 - val_accuracy: 0.6927
# Average training accuracy of last 10 epochs: 0.6447071194648742%
# Average validation accuracy of last 10 epochs: 0.7113475143909455%
# Finished training.
#
# Testing on data from all subjects.
# 0.6004514694213867% accuracy on data from all subjects.

# %% [markdown]
# #LSTM

# %%
# hyper params
# Model parameters
num_filters = [50, 100, 200]
filter_size = 5
dropout = 0.6
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.4
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples

# Training parameters
epochs = 20
batch_size = 100
lr = 1e-3
verbose = True


# call the cnn+lstm+gru model 2
model = lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, time_limit)
print("\nBuilding train/val data")
x_train, y_train, x_val, y_val = train_val_data(subjects=None, time_limit=time_limit)
print("Using " + str(len(x_train)) + " training examples & " + str(len(x_val)) + " validation examples.")
print("\nTraining...")
_,_,trAcc, valAcc,trLoss,valLoss = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
print("Finished training.")

print("\nTesting on data from all subjects.")
x_te, y_te = test_data(time_limit=time_limit)
acc = test(model, x_te, y_te)
print(str(acc) + "% accuracy on data from all subjects.")

import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(valAcc)
plt.plot(trAcc)
plt.title('RNN Only (LSTM) Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(valLoss,'o')
plt.plot(trLoss,'o')
plt.title('RNN Only (LSTM) Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Building train/val data
# Shape of X after averaging+noise and concatenating: (4230, 22, 400)
# Using 7614 training examples & 846 validation examples.
#
# Training...
# Epoch 1/20
# 77/77 [==============================] - 34s 394ms/step - loss: 1.3903 - accuracy: 0.2748 - val_loss: 1.3931 - val_accuracy: 0.2790
# Epoch 2/20
# 77/77 [==============================] - 26s 338ms/step - loss: 1.3798 - accuracy: 0.2795 - val_loss: 1.3795 - val_accuracy: 0.2931
# Epoch 3/20
# 77/77 [==============================] - 27s 345ms/step - loss: 1.3737 - accuracy: 0.2904 - val_loss: 1.3871 - val_accuracy: 0.2884
# Epoch 4/20
# 77/77 [==============================] - 26s 333ms/step - loss: 1.3692 - accuracy: 0.2918 - val_loss: 1.3660 - val_accuracy: 0.3038
# Epoch 5/20
# 77/77 [==============================] - 27s 354ms/step - loss: 1.3595 - accuracy: 0.3161 - val_loss: 1.3666 - val_accuracy: 0.3085
# Epoch 6/20
# 77/77 [==============================] - 26s 336ms/step - loss: 1.3422 - accuracy: 0.3361 - val_loss: 1.3536 - val_accuracy: 0.3310
# Epoch 7/20
# 77/77 [==============================] - 26s 343ms/step - loss: 1.3235 - accuracy: 0.3625 - val_loss: 1.3378 - val_accuracy: 0.3546
# Epoch 8/20
# 77/77 [==============================] - 26s 339ms/step - loss: 1.3055 - accuracy: 0.3901 - val_loss: 1.3215 - val_accuracy: 0.3865
# Epoch 9/20
# 77/77 [==============================] - 27s 346ms/step - loss: 1.2817 - accuracy: 0.4132 - val_loss: 1.2908 - val_accuracy: 0.4113
# Epoch 10/20
# 77/77 [==============================] - 27s 347ms/step - loss: 1.2564 - accuracy: 0.4301 - val_loss: 1.2653 - val_accuracy: 0.4184
# Epoch 11/20
# 77/77 [==============================] - 26s 338ms/step - loss: 1.2310 - accuracy: 0.4480 - val_loss: 1.2352 - val_accuracy: 0.4456
# Epoch 12/20
# 77/77 [==============================] - 26s 334ms/step - loss: 1.1966 - accuracy: 0.4704 - val_loss: 1.2197 - val_accuracy: 0.4563
# Epoch 13/20
# 77/77 [==============================] - 26s 327ms/step - loss: 1.1780 - accuracy: 0.4867 - val_loss: 1.2027 - val_accuracy: 0.4669
# Epoch 14/20
# 77/77 [==============================] - 27s 351ms/step - loss: 1.1507 - accuracy: 0.4941 - val_loss: 1.1962 - val_accuracy: 0.4693
# Epoch 15/20
# 77/77 [==============================] - 26s 329ms/step - loss: 1.1291 - accuracy: 0.5070 - val_loss: 1.2105 - val_accuracy: 0.4291
# Epoch 16/20
# 77/77 [==============================] - 26s 331ms/step - loss: 1.1073 - accuracy: 0.5205 - val_loss: 1.1506 - val_accuracy: 0.5083
# Epoch 17/20
# 77/77 [==============================] - 29s 375ms/step - loss: 1.0612 - accuracy: 0.5436 - val_loss: 1.0969 - val_accuracy: 0.5319
# Epoch 18/20
# 77/77 [==============================] - 33s 415ms/step - loss: 1.0316 - accuracy: 0.5650 - val_loss: 1.0791 - val_accuracy: 0.5296
# Epoch 19/20
# 77/77 [==============================] - 26s 344ms/step - loss: 0.9888 - accuracy: 0.5883 - val_loss: 1.0271 - val_accuracy: 0.5709
# Epoch 20/20
# 77/77 [==============================] - 27s 346ms/step - loss: 0.9461 - accuracy: 0.6108 - val_loss: 0.9938 - val_accuracy: 0.5993
# Average training accuracy of last 10 epochs: 0.5234436511993408%
# Average validation accuracy of last 10 epochs: 0.5007092177867889%
# Finished training.
#
# Testing on data from all subjects.
# 0.3431151211261749% accuracy on data from all subjects.

# %% [markdown]
# #Further Questioning

# %% [markdown]
# ### Hyperparameter Optimization
# This block of code is designed specifically to help with optimization of hyperparameters. By iteratively training separate models while varying hyperparameters, we can attempt to understand how we should adjust the model for optimal performance.

# %%
filter_options = [
    #[32],
    [50, 100, 200]                  # filter size 5: 42.3%                            3: 41.3%
    #[25, 50, 100, 200],           # Result with filter size 5 (5 epochs): 47%       filter size 3: 40.4%
    #[25, 50, 100, 200, 400],      # Result with filter size 5 (5 epochs): 37.5%     filter size 3: 33.1%
    #[25, 50, 100, 100, 200, 200]  # Result with filter size 5 (5 epochs): 41.6%     filter size 3: 24.8%
]

for option in filter_options:
  print("\nTesting for filters:", option)
  model = cnn_lstm(num_filters = option, filter_size = 3, recurrent_dropout = 0.2, lstm_dropout = 0.3, dropout = 0.4)

  x_train, y_train, x_val, y_val = train_val_data()
  x_te, y_te = test_data()

  train(model, x_train, y_train, x_val, y_val, epochs = 3, verbose = True)
  print("Test accuracy:" + str(test(model, x_te, y_te)))

# %% [markdown]
# ### Accuracy as a function of time
# In this block of code, the goal is to determine how accuracy is impacted by the duration of the trial. To do so, we train separate models with different lengths of trials, and compare their performance.

# %%
# Model parameters
num_filters = [25, 50, 100, 200]
filter_size = 3
dropout = 0.6
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.4
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples


# Training parameters
epochs = 50
batch_size = 200
lr = 1e-3
verbose = False


print("#### Determining accuracy as a function of time ####")
time_limits = [10, 30, 50, 100, 200, 300, 400, 500, 600, 800, 1000]
print("Testing for times:", time_limits)
train_accs, val_accs, test_accs = [], [], []
for limit in time_limits:
  print("Testing for time_limit="+str(limit)+"...")
  model = cnn_lstm(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, limit)
  x_train, y_train, x_val, y_val = train_val_data(time_limit=limit)
  x_te, y_te = test_data(time_limit=limit)
  end_avg_train_acc, end_avg_val_acc = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
  test_acc = test(model, x_te, y_te)

  train_accs.append(end_avg_train_acc)
  val_accs.append(end_avg_val_acc)
  test_accs.append(test_acc)

plt.plot(time_limits, train_accs)
plt.plot(time_limits, val_accs)
plt.plot(time_limits, test_accs)
plt.legend(['Training Acc.', 'Validation Acc.', 'Test Acc.'])
plt.xlabel('Time')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### Training on a single subject
# In the following block of code, we experiment with training a model exclusively on a single subject's data. We then test it first on data from that same subject, then data from all subjects to see how it generalizes.

# %%
# Model parameters
num_filters = [25, 50, 100, 200]
filter_size = 5
dropout = 0.6
activation_func = 'elu'
dense_size = 100
lstm_dropout = 0.4
recurrent_dropout = 0.1
time_limit=800 # Cuts data at this number of samples


# Training parameters
epochs = 80
batch_size = 200
lr = 1e-3
verbose = True


print("#### Determining accuracy as a function of time ####")
time_limits = [800]
print("Testing for times:", time_limits)
train_accs, val_accs, test_accs = [], [], []
for limit in time_limits:
  print("Testing for time_limit="+str(limit)+"...")
  model = cnn_bi(num_filters, filter_size, dropout, activation_func, dense_size, lstm_dropout, recurrent_dropout, limit)
  x_train, y_train, x_val, y_val = train_val_data(time_limit=limit)
  x_te, y_te = test_data(time_limit=limit)
  end_avg_train_acc, end_avg_val_acc = train(model, x_train, y_train, x_val, y_val, epochs, batch_size, lr, verbose)
  test_acc = test(model, x_te, y_te)

  train_accs.append(end_avg_train_acc)
  val_accs.append(end_avg_val_acc)
  test_accs.append(test_acc)
